# %%
import easyocr
import requests
from io import BytesIO
from PIL import Image
reader = easyocr.Reader(['en'])
def ocr_img_from_url(img_url):
    try:
        response = requests.get(img_url, stream=True)
        if response.status_code != 200:
            print(f"Failed to fetch: {img_url} (Status: {response.status_code})")
            return ""

        # Read image as bytes
        img_bytes = response.content
        
        # Use EasyOCR directly with bytes
        result = reader.readtext(img_bytes)

        # Extract text with high confidence
        text_result = " ".join(text for _, text, prob in result if prob > 0.5)

        return text_result if text_result else "(No text found)"

    except Exception as e:
        print(f"Error processing {img_url}: {e}")
        return ""

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('Coin.csv')
df = df[['id', 'address', 'name', 'symbol', 'description', 'mediumImageUrl', 'mimeType']]
df = df.dropna(subset='mediumImageUrl')

# %%
df['img_text'] = df['mediumImageUrl'].apply(lambda x: ocr_img_from_url(x))

# %%
df[df['img_text'] != '(No text found)']
# Out:
#                                                      id  \
# 5     R3JhcGhRTFpvcmEyMFRva2VuOkJBU0UtTUFJTk5FVC4weD...
# 16    R3JhcGhRTFpvcmEyMFRva2VuOkJBU0UtTUFJTk5FVC4weD...
# 18    R3JhcGhRTFpvcmEyMFRva2VuOkJBU0UtTUFJTk5FVC4weD...
# 28    R3JhcGhRTFpvcmEyMFRva2VuOkJBU0UtTUFJTk5FVC4weD...
# 36    R3JhcGhRTFpvcmEyMFRva2VuOkJBU0UtTUFJTk5FVC4weD...
# ...                                                 ...
# 5878  R3JhcGhRTFpvcmEyMFRva2VuOkJBU0UtTUFJTk5FVC4weG...
# 5880  R3JhcGhRTFpvcmEyMFRva2VuOkJBU0UtTUFJTk5FVC4weG...
# 5881  R3JhcGhRTFpvcmEyMFRva2VuOkJBU0UtTUFJTk5FVC4weG...
# 5882  R3JhcGhRTFpvcmEyMFRva2VuOkJBU0UtTUFJTk5FVC4weG...
# 5883  R3JhcGhRTFpvcmEyMFRva2VuOkJBU0UtTUFJTk5FVC4weG...
#
#                                          address  \
# 5     0x044288976c45fd7ee1b6479fd6c451fcc6874bc9
# 16    0x049daba418280c4a3c7c3928427b9e01d3f904ad
# 18    0x04cf6d968bc2e1bf7eb51122075c1c45baa379f6
# 28    0x04fdf7c6c556e07ece1a7e58568958e798014be2
# 36    0x056b3eb526b5392c8a1e0701aff02092b82efe97
# ...                                          ...
# 5878  0xff91b1f111cbf00f3ade145bbdee26002777935f
# 5880  0xff95f43e31ebb3d730b7215c7ec39c31a8ce18ce
# 5881  0xffce508ba588a789361c684b6c2e5f4abdbcbc99
# 5882  0xffac1ff4466f47da4161d6166993d327cd8f6fec
# 5883  0xffb7b71c3b611eb0405ff2bdd9cefdd52590b588
#
#                                              name  \
# 5                                             🧿🧿🧿
# 16                               human democratic
# 18                                       GoldZorb
# 28                                       kiemtien
# 36                                     sportGTcar
# ...                                           ...
# 5878                       Squid game controllers
# 5880                            17.03.2025, 17:34
# 5881                                       werwer
# 5882  Base builders chilling and building on Base
# 5883                                5/3/25, 09:39
#
#                                            symbol  \
# 5                                             🧿🧿🧿
# 16                               human democratic
# 18                                       GoldZorb
# 28                                       kiemtien
# 36                                     sportGTcar
# ...                                           ...
# 5878                       Squid game controllers
# 5880                            17.03.2025, 17:34
# 5881                                       werwer
# 5882  Base builders chilling and building on Base
# 5883                                5/3/25, 09:39
#
#                                         description  \
# 5                                               NaN
# 16                                              NaN
# 18                                         GoldZorb
# 28                                              NaN
# 36                                              NaN
# ...                                             ...
# 5878                                            NaN
# 5880  Different types of the \nlaughing condition.
# 5881                                            NaN
# 5882                                            NaN
# 5883                         Toi ngheo ban cung the
#
#                                          mediumImageUrl  \
# 5     https://media.decentralized-content.com/-/rs:f...
# 16    https://media.decentralized-content.com/-/rs:f...
# 18    https://media.decentralized-content.com/-/rs:f...
# 28    https://media.decentralized-content.com/-/rs:f...
# 36    https://media.decentralized-content.com/-/rs:f...
# ...                                                 ...
# 5878  https://media.decentralized-content.com/-/rs:f...
# 5880  https://media.decentralized-content.com/-/rs:f...
# 5881  https://media.decentralized-content.com/-/rs:f...
# 5882  https://media.decentralized-content.com/-/rs:f...
# 5883  https://media.decentralized-content.com/-/rs:f...
#
#                        mimeType  \
# 5                     image/gif
# 16                    image/png
# 18                   image/jpeg
# 28                    image/png
# 36                   image/jpeg
# ...                         ...
# 5878                 image/jpeg
# 5880                  video/mp4
# 5881  text/plain; charset=utf-8
# 5882                 image/jpeg
# 5883                 image/jpeg
#
#                                                img_text
# 5
# 16                                                    1
# 18                                                 ZORA
# 28                                               Seeing
# 36                                               GT? RS
# ...                                                 ...
# 5878                                                  0
# 5880                                               #aha
# 5881                                             werwer
# 5882  Others stress over high gas fees and slow tran...
# 5883                                                 25
#
# [1534 rows x 8 columns]

# %%
df
